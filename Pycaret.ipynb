# %%
# !pip install --pre pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 26.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/Cleaned_Preprocessed_CKD.csv")
df.head()
# Out:
#    Unnamed: 0  age  blood_pressure  specific_gravity  albumin  sugar  \
# 0           0   48              80             1.020        1      0
# 1           1    7              50             1.020        4      0
# 2           2   62              80             1.010        2      3
# 3           3   48              70             1.005        4      0
# 4           4   51              80             1.010        2      0
#
#    red_blood_cells  pus_cell  pus_cell_clumps  bacteria  ...  \
# 0                1         1                0         0  ...
# 1                1         1                0         0  ...
# 2                1         1                0         0  ...
# 3                1         0                1         0  ...
# 4                1         1                0         0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                  44                    7800                   5.2
# ...

# %%
df.isnull().sum().all()
# Out:
# False

# %%
df.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
data= df.interpolate();
print(data)
# Out:
#      Unnamed: 0  age  blood_pressure  specific_gravity  albumin  sugar  \
# 0             0   48              80             1.020        1      0
# 1             1    7              50             1.020        4      0
# 2             2   62              80             1.010        2      3
# 3             3   48              70             1.005        4      0
# 4             4   51              80             1.010        2      0
# ..          ...  ...             ...               ...      ...    ...
# 395         395   55              80             1.020        0      0
# 396         396   42              70             1.025        0      0
# 397         397   12              80             1.020        0      0
# 398         398   17              60             1.025        0      0
# 399         399   58              80             1.025        0      0
#
#      red_blood_cells  pus_cell  pus_cell_clumps  bacteria  ...  \
# ...

# %%
# !pip install markupsafe==2.0.1

# %%
import pandas as pd
import numpy as np

# Convert the 'Timestamp' column to a numeric datetime representation
data['Timestamp'] = pd.to_datetime(data['Timestamp'], format='%Y-%m-%d %H:%M:%S.%f%z')  # Include milliseconds in the format
data['Timestamp'] = data['Timestamp'].astype(np.int64) // 10**9  # Convert to Unix timestamp (seconds)
print(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-838156a1cc39> in <cell line: 5>()
#       3
#       4 # Convert the 'Timestamp' column to a numeric datetime representation
# ----> 5 data['Timestamp'] = pd.to_datetime(data['Timestamp'], format='%Y-%m-%d %H:%M:%S.%f%z')  # Include milliseconds in the format
#       6 data['Timestamp'] = data['Timestamp'].astype(np.int64) // 10**9  # Convert to Unix timestamp (seconds)
#       7 print(data)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048             result = arg.map(cache_array)
#    1049         else:
# -> 1050             values = convert_listlike(arg._values, format)
#    1051             result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
from pycaret.classification import *
s = setup(data, target = 'class')
# Out:
# <style type="text/css">
# #T_cb5f3_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cb5f3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb5f3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cb5f3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb5f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb5f3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cb5f3_row0_col1" class="data row0 col1" >5861</td>
#     </tr>
#     <tr>
#       <th id="T_cb5f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb5f3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cb5f3_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_cb5f3_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
import pandas as pd

# Load your data (adjust the file path as necessary)
df = pd.read_csv('/content/cleaned_data.csv')

# Assuming the timestamp column is named 'timestamp' and the truncated timestamp is 'truncated_timestamp'
# If not, replace 'timestamp' with your column name
df['truncated_timestamp'] = pd.to_datetime(df['Timestamp'])

# Now set the datetime column as the index
df.set_index('truncated_timestamp', inplace=True)

# Convert any numerical columns to numeric types if necessary
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
print(df.dtypes)
# Out:
# Num                       int64
# Timestamp               float64
# Current_J0              float64
# Temperature_T0          float64
# Current_J1              float64
# Temperature_J1          float64
# Current_J2              float64
# Temperature_J2          float64
# Current_J3              float64
# Temperature_J3          float64
# Current_J4              float64
# Temperature_J4          float64
# Current_J5              float64
# Temperature_J5          float64
# Speed_J0                float64
# Speed_J1                float64
# Speed_J2                float64
# Speed_J3                float64
# Speed_J4                float64
# Speed_J5                float64
# Tool_current            float64
# cycle                     int64
# Robot_ProtectiveStop      int64
# grip_lost                  bool
# dtype: object

# %%
df.head()
# Out:
#                      Num  Current_J0  Temperature_T0  Current_J1  \
# Timestamp
# 2022-10-26 08:17:21    1    0.109628          27.875   -2.024669
# 2022-10-26 08:17:22    2    0.595605          27.875   -2.278456
# 2022-10-26 08:17:23    3   -0.229474          27.875   -2.800408
# 2022-10-26 08:17:24    4    0.065053          27.875   -3.687768
# 2022-10-26 08:17:25    5    0.884140          27.875   -2.938830
#
#                      Temperature_J1  Current_J2  Temperature_J2  Current_J3  \
# Timestamp
# 2022-10-26 08:17:21         29.3750   -1.531442         29.3750   -0.998570
# 2022-10-26 08:17:22         29.3125   -0.866556         29.4375   -0.206097
# 2022-10-26 08:17:23         29.3125   -2.304336         29.4375   -0.351499
# 2022-10-26 08:17:24         29.3125   -1.217652         29.4375   -1.209115
# 2022-10-26 08:17:25         29.3750   -1.794076         29.4375   -2.356471
#
#                      Temperature_J3  Current_J4  ...      Speed_J0  Speed_J1  \
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_b6bd8 th {
#   text-align: left;
# }
# ...

# %%
plot_model(best)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-d26e9b1c0d3c> in <cell line: 1>()
# ----> 1 plot_model(best)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/regression/functional.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, verbose, display_format)
#    1644     """
#    1645
# -> 1646     return _CURRENT_EXPERIMENT.plot_model(
#    1647         estimator=estimator,
#    1648         plot=plot,
#
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(best)

# %%
evaluate_model(best)

# %%
rf = create_model('et')
# Out:
# <style type="text/css">
# #T_2ba37_row10_col0, #T_2ba37_row10_col1, #T_2ba37_row10_col2, #T_2ba37_row10_col3, #T_2ba37_row10_col4, #T_2ba37_row10_col5, #T_2ba37_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2ba37" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ba37_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2ba37_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2ba37_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2ba37_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2ba37_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2ba37_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2ba37_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_6f1e6_row10_col0, #T_6f1e6_row10_col1, #T_6f1e6_row10_col2, #T_6f1e6_row10_col3, #T_6f1e6_row10_col4, #T_6f1e6_row10_col5, #T_6f1e6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6f1e6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f1e6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6f1e6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6f1e6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6f1e6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6f1e6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6f1e6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6f1e6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
print(rf)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=7487, verbose=0,
#                      warm_start=False)

# %%
print(tuned_rf)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=7487, verbose=0,
#                      warm_start=False)
