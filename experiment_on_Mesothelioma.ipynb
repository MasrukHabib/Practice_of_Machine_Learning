# %% [markdown]
# <a href="https://colab.research.google.com/github/MasrukHabib/Practice-of-Machine-Learning/blob/main/experiment_on_Mesothelioma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mount with Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/Main_Mesothelioma_Data_Set.csv")
df.head()
# Out:
#    age  gender  city  asbestos exposure  type of MM  \
# 0   47       1     0                  1           0
# 1   55       1     0                  1           0
# 2   29       1     1                  1           0
# 3   39       1     0                  1           0
# 4   47       1     0                  1           0
#
#    duration of asbestos exposure  diagnosis method  keep side  cytology  \
# 0                             20                 1          0         1
# 1                             45                 1          0         0
# 2                             23                 0          1         0
# 3                             10                 1          0         0
# 4                             10                 1          1         1
#
#    duration of symptoms  ...  pleural lactic dehydrogenise  pleural protein  \
# 0                  24.0  ...                           289              0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age                               324 non-null    int64
#  1   gender                            324 non-null    int64
#  2   city                              324 non-null    int64
#  3   asbestos exposure                 324 non-null    int64
#  4   type of MM                        324 non-null    int64
#  5   duration of asbestos exposure     324 non-null    int64
#  6   diagnosis method                  324 non-null    int64
#  7   keep side                         324 non-null    int64
#  8   cytology                          324 non-null    int64
#  9   duration of symptoms              324 non-null    float64
#  10  dyspnoea                          324 non-null    int64
#  11  ache on chest                     324 non-null    int64
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = df[col].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age                               324 non-null    int64
#  1   gender                            324 non-null    int64
#  2   city                              324 non-null    int64
#  3   asbestos exposure                 324 non-null    int64
#  4   type of MM                        324 non-null    int64
#  5   duration of asbestos exposure     324 non-null    int64
#  6   diagnosis method                  324 non-null    int64
#  7   keep side                         324 non-null    int64
#  8   cytology                          324 non-null    int64
#  9   duration of symptoms              324 non-null    int64
#  10  dyspnoea                          324 non-null    int64
#  11  ache on chest                     324 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# age                                 0
# gender                              0
# city                                0
# asbestos exposure                   0
# type of MM                          0
# duration of asbestos exposure       0
# diagnosis method                    0
# keep side                           0
# cytology                            0
# duration of symptoms                0
# dyspnoea                            0
# ache on chest                       0
# weakness                            0
# habit of cigarette                  0
# performance status                  0
# white blood                         0
# cell count (WBC)                    0
# hemoglobin (HGB)                    0
# platelet count (PLT)                0
# sedimentation                       0
# blood lactic dehydrogenise (LDH)    0
# alkaline phosphatise (ALP)          0
# total protein                       0
# albumin                             0
# glucose                             0
# ...

# %%
df.replace('?', 'Nan', inplace=True)

# %%
df.isnull().sum()
# Out:
# age                                 0
# gender                              0
# city                                0
# asbestos exposure                   0
# type of MM                          0
# duration of asbestos exposure       0
# diagnosis method                    0
# keep side                           0
# cytology                            0
# duration of symptoms                0
# dyspnoea                            0
# ache on chest                       0
# weakness                            0
# habit of cigarette                  0
# performance status                  0
# white blood                         0
# cell count (WBC)                    0
# hemoglobin (HGB)                    0
# platelet count (PLT)                0
# sedimentation                       0
# blood lactic dehydrogenise (LDH)    0
# alkaline phosphatise (ALP)          0
# total protein                       0
# albumin                             0
# glucose                             0
# ...

# %%
df.head()
# Out:
#    age  gender  city  asbestos exposure  type of MM  \
# 0   47       1     0                  1           0
# 1   55       1     0                  1           0
# 2   29       1     1                  1           0
# 3   39       1     0                  1           0
# 4   47       1     0                  1           0
#
#    duration of asbestos exposure  diagnosis method  keep side  cytology  \
# 0                             20                 1          0         1
# 1                             45                 1          0         0
# 2                             23                 0          1         0
# 3                             10                 1          0         0
# 4                             10                 1          1         1
#
#    duration of symptoms  ...  pleural lactic dehydrogenise  pleural protein  \
# 0                    24  ...                           289                0
# ...

# %%
df
# Out:
#      age  gender  city  asbestos exposure  type of MM  \
# 0     47       1     0                  1           0
# 1     55       1     0                  1           0
# 2     29       1     1                  1           0
# 3     39       1     0                  1           0
# 4     47       1     0                  1           0
# ..   ...     ...   ...                ...         ...
# 319   75       1     1                  1           0
# 320   66       1     1                  1           0
# 321   58       1     6                  1           0
# 322   42       1     6                  0           0
# 323   54       1     0                  1           0
#
#      duration of asbestos exposure  diagnosis method  keep side  cytology  \
# 0                               20                 1          0         1
# 1                               45                 1          0         0
# 2                               23                 0          1         0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Calculate correlation matrix
corr_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(15, 8))
plt.title('Correlation Matrix', fontsize=11)

# Create a heatmap
sns.heatmap(corr_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".2f",
            linewidths=0.5,
            annot_kws={"size": 14})

# Add aesthetics
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
# Show plot
plt.show()

# %%
# Define feature matrix X and target vector y
X = df.drop('class of diagnosis', axis=1)
y = df['class of diagnosis']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
import pandas as pd

# Calculate class distribution
class_distribution = df['class of diagnosis'].value_counts()

# Print class distribution
print("Class Distribution:")
print(class_distribution)

# Check if data is balanced
balanced = class_distribution.min() / class_distribution.max() >= 0.5

if balanced:
    print("The data is balanced.")
else:
    print("The data is imbalanced.")
# Out:
# Class Distribution:
# class of diagnosis
# 1    228
# 2     96
# Name: count, dtype: int64
# The data is imbalanced.

# %% [markdown]
# 1= negative
# 2= possitive

# %%
import numpy as np
import matplotlib.pyplot as plt

# Plotting the balance of the target variable
plt.figure(figsize=(10, 5))

# Bar plot
plt.subplot(1, 2, 1)
sns.countplot(x=y)
plt.title('Class Distribution')
plt.xlabel('class of diagnosis')
plt.ylabel('Count')

# Pie chart
plt.subplot(1, 2, 2)
y.value_counts().plot.pie(autopct='%1.1f%%', colors=['skyblue', 'lightgreen'])
plt.title('Class Distribution')
plt.ylabel('')  # Hide y-label for the pie chart

plt.tight_layout()
plt.show()

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

# Apply SMOTE
smote = SMOTE(sampling_strategy='auto')
X_res, y_res = smote.fit_resample(X, y)

# Create a new DataFrame with the balanced data
balanced_df = pd.concat([X_res, y_res], axis=1)

# Display the class distribution of the balanced data
print(balanced_df['class of diagnosis'].value_counts())
# Out:
# class of diagnosis
# 1    228
# 2    228
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Class distribution data
class_counts = {'Class 1': 228, 'Class 2': 228}

# Create bar chart
plt.figure(figsize=(8, 6))
plt.bar(class_counts.keys(), class_counts.values(), color=['blue', 'orange'])
plt.xlabel('Class of Diagnosis')
plt.ylabel('Count')
plt.title('Class Distribution of Diagnosis')
plt.ylim(0, 250)
plt.show()

# %%
# Import necessary libraries
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize and train the classifier
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

# Predict the labels for the test set
y_pred = classifier.predict(X_test)

# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")

# Add labels, title and show the plot
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize classifiers
classifiers = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Support Vector Machine': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Extra Trees': ExtraTreesClassifier(),
    'Naive Bayes': GaussianNB()
}

# Evaluate classifiers
for name, clf in classifiers.items():
    clf.fit(X_train_scaled, y_train)
    y_pred = clf.predict(X_test_scaled)

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Print results
    print(f"{name}:")
    print(f"  Accuracy: {accuracy:.3f}")
    print(f"  Precision: {precision:.3f}")
    print(f"  Recall: {recall:.3f}")
    print(f"  F1 Score: {f1:.3f}")
    print()
# Out:
# Logistic Regression:
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1 Score: 1.000
#
# Decision Tree:
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1 Score: 1.000
#
# Support Vector Machine:
#   Accuracy: 0.992
#   Precision: 0.989
#   Recall: 1.000
#   F1 Score: 0.995
#
# K-Nearest Neighbors:
#   Accuracy: 0.885
#   Precision: 0.869
#   Recall: 0.989
#   F1 Score: 0.925
#
# Extra Trees:
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1 Score: 1.000
#
# Naive Bayes:
#   Accuracy: 1.000
#   Precision: 1.000
#   Recall: 1.000
#   F1 Score: 1.000
